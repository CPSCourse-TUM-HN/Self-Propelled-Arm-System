# %% [markdown]
# # Base Speed and Time Calibration
#
# Edit `base_speed_time_parameters.json`, then use **Reload JSON**. Real motion is disabled by default. Each run gets a `run_id` and is written immediately under `logs/base_speed_time/`. Enter the measured angle/distance afterward and use **Record Measurement** to calculate turn response, recommended 90-degree duration, and left/right scale suggestions.

# %%
from __future__ import print_function
import os, sys
current = os.path.abspath(os.getcwd())
for _ in range(5):
    if os.path.isfile(os.path.join(current, 'config.json')):
        PROJECT_ROOT = current
        break
    current = os.path.dirname(current)
else:
    raise RuntimeError('config.json not found')
TUNING_DIR = os.path.join(PROJECT_ROOT, 'tuning_tools')
for path in (PROJECT_ROOT, TUNING_DIR):
    if path not in sys.path: sys.path.insert(0, path)
from base_speed_time_calibration import build_ui
calibration_panel = build_ui()
